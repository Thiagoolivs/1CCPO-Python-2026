# %%
notaA = float(input("Digite a primeira nota: "))
while notaA < 0 or notaA > 10:
    print(f"A nota deve estar entre 0 e 10")
    notaA = float(input("Digite a nota novamente: "))

#notaB = float(input("Digite a segunda nota: "))
# Out:
# A nota deve estar entre 0 e 10

# %%
def verificaNota(nota):
    while nota < 0 or notaA > 10:
        print("A nota deve estar entre 0 e 10")
        nota= float(input("Digite a nota novamente: "))
    return nota

notaA = float(input("Digite a primeira nota: "))
notaA = verificaNota(notaA)
# Out:
# A nota deve estar entre 0 e 10
# A nota deve estar entre 0 e 10
# A nota deve estar entre 0 e 10
# A nota deve estar entre 0 e 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       4         nota= float(input("Digite a nota novamente: "))
#       5     return nota
#       6
#       7 notaA = float(input("Digite a primeira nota: "))
# ----> 8 notaA = verificaNota(notaA)
#
# Cell In[3], line 4, in verificaNota(nota)
#       1 def verificaNota(nota):
#       2     while nota < 0 or notaA > 10:
#       3         print("A nota deve estar entre 0 e 10")
# ----> 4         nota= float(input("Digite a nota novamente: "))
#       5     return nota
#
# File ~\PycharmProjects\1CCPO-Python-2026\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\PycharmProjects\1CCPO-Python-2026\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
